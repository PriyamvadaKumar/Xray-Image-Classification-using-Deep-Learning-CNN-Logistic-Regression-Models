# %%
#importing libraries
import PIL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential 
from keras.layers import Convolution2D ,MaxPooling2D, Flatten, Dense,Dropout
from keras.utils import to_categorical
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
#from keras.layers import BatchNormalization
import shutil
import random
import os
import numpy as np
import warnings
warnings.filterwarnings('ignore')
##
seed=10
np.random.seed(seed)
# Out:
# Using TensorFlow backend.

# %%
#initialise the CNN model with different layers(used sequential): 3 layers
model = Sequential()
# Note the input shape is the desired size of the image 300x300 with 3 bytes color
# Step 1
model.add(Convolution2D(16,3,3, input_shape=(500, 500, 3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
#step 2 Convolution- learn features: put convolution filter on input(5X5) to get tensor output
model.add(Convolution2D(32,3,3, activation="relu"))

#step 3 Normalize the activations of the previous layer at each batch to increase stability and performance 
#model.add(BatchNormalization())

#step 4 reduce spatial dimension 
model.add(MaxPooling2D(pool_size =(2,2)))

#step 5 learn more features with activation function 'relu'to introduce non-lineraity (& avoid overfitting )
model.add(Convolution2D(64, 3, 3, activation = 'relu'))

#step 6 reduce spatial dimension
model.add(MaxPooling2D(pool_size=(2,2)))

#step 7 multidimensional to linear output
model.add(Flatten())

#step 8 connect every input to every output by weights (dot product)
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation = 'softmax'))

# %%
#loss function is default for multi-classification problem  
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
#augmentation configuration for training and testing 
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)



test_datagen = ImageDataGenerator(rescale = 1./255)
# used this code when I manually put images in folder train under CHEST_xrxay/train.
#now has to be done ramdomly with code because manually picking images to train etc is not good
# Can comment out if need be
#32
training_set = train_datagen.flow_from_directory('CHEST_xray/train',
                                                target_size = (500, 500),
                                                batch_size = 32,
                                                class_mode = 'categorical')
# Out:
# Found 2032 images belonging to 3 classes.

# %%
#used this code when I manually put images in folder train under CHEST_xrxay/validate
#now has to be done ramdomly with code because manually picking images is not good
# Can comment out if need be
validation_set = test_datagen.flow_from_directory('CHEST_xray/validate',
                                                target_size = (500, 500),
                                                batch_size = 32,
                                                class_mode = 'categorical')
# Out:
# Found 726 images belonging to 3 classes.

# %%
history=model.fit_generator(training_set,epochs =30,steps_per_epoch=62 ,validation_data = validation_set)
# Out:
# WARNING:tensorflow:From <ipython-input-6-e3d283b9505c>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/30
# 62/62 [==============================] - 146s 2s/step - loss: 0.9467 - accuracy: 0.5158 - val_loss: 0.8841 - val_accuracy: 0.4642
# Epoch 2/30
# 62/62 [==============================] - 144s 2s/step - loss: 0.7652 - accuracy: 0.6133 - val_loss: 0.7740 - val_accuracy: 0.6818
# Epoch 3/30
# 62/62 [==============================] - 164s 3s/step - loss: 0.6578 - accuracy: 0.7322 - val_loss: 0.5236 - val_accuracy: 0.8058
# Epoch 4/30
# 62/62 [==============================] - 156s 3s/step - loss: 0.5536 - accuracy: 0.7617 - val_loss: 0.4148 - val_accuracy: 0.8375
# Epoch 5/30
# 62/62 [==============================] - 150s 2s/step - loss: 0.4954 - accuracy: 0.8028 - val_loss: 0.3970 - val_accuracy: 0.8595
# Epoch 6/30
# 62/62 [==============================] - 148s 2s/step - loss: 0.4519 - accuracy: 0.8308 - val_loss: 0.3559 - val_accuracy: 0.8719
# Epoch 7/30
# 62/62 [==============================] - 145s 2s/step - loss: 0.4485 - accuracy: 0.8308 - val_loss: 0.4165 - val_accuracy: 0.8375
# Epoch 8/30
# 62/62 [==============================] - 145s 2s/step - loss: 0.4302 - accuracy: 0.8435 - val_loss: 0.3738 - val_accuracy: 0.8705
# Epoch 9/30
# 62/62 [==============================] - 143s 2s/step - loss: 0.4128 - accuracy: 0.8506 - val_loss: 0.3134 - val_accuracy: 0.8884
# Epoch 10/30
# 62/62 [==============================] - 144s 2s/step - loss: 0.3480 - accuracy: 0.8659 - val_loss: 0.2819 - val_accuracy: 0.8884
# Epoch 11/30
# 62/62 [==============================] - 142s 2s/step - loss: 0.3808 - accuracy: 0.8664 - val_loss: 0.3438 - val_accuracy: 0.8774
# Epoch 12/30
# 62/62 [==============================] - 143s 2s/step - loss: 0.3613 - accuracy: 0.8659 - val_loss: 0.3241 - val_accuracy: 0.8829
# Epoch 13/30
# 62/62 [==============================] - 142s 2s/step - loss: 0.3614 - accuracy: 0.8653 - val_loss: 0.2839 - val_accuracy: 0.8967
# Epoch 14/30
# 62/62 [==============================] - 145s 2s/step - loss: 0.3504 - accuracy: 0.8786 - val_loss: 0.2967 - val_accuracy: 0.8884
# Epoch 15/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3682 - accuracy: 0.8653 - val_loss: 0.2933 - val_accuracy: 0.8912
# Epoch 16/30
# 62/62 [==============================] - 145s 2s/step - loss: 0.3916 - accuracy: 0.8491 - val_loss: 0.3112 - val_accuracy: 0.8898
# Epoch 17/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3448 - accuracy: 0.8628 - val_loss: 0.2937 - val_accuracy: 0.9008
# Epoch 18/30
# 62/62 [==============================] - 139s 2s/step - loss: 0.3692 - accuracy: 0.8491 - val_loss: 0.2931 - val_accuracy: 0.8857
# Epoch 19/30
# 62/62 [==============================] - 139s 2s/step - loss: 0.3378 - accuracy: 0.8780 - val_loss: 0.3259 - val_accuracy: 0.8719
# Epoch 20/30
# 62/62 [==============================] - 139s 2s/step - loss: 0.3259 - accuracy: 0.8740 - val_loss: 0.2931 - val_accuracy: 0.8898
# Epoch 21/30
# 62/62 [==============================] - 141s 2s/step - loss: 0.3250 - accuracy: 0.8847 - val_loss: 0.3152 - val_accuracy: 0.8815
# Epoch 22/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3146 - accuracy: 0.8887 - val_loss: 0.2638 - val_accuracy: 0.8953
# Epoch 23/30
# 62/62 [==============================] - 142s 2s/step - loss: 0.3504 - accuracy: 0.8648 - val_loss: 0.2655 - val_accuracy: 0.8981
# Epoch 24/30
# 62/62 [==============================] - 142s 2s/step - loss: 0.3378 - accuracy: 0.8760 - val_loss: 0.2652 - val_accuracy: 0.8857
# Epoch 25/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3273 - accuracy: 0.8862 - val_loss: 0.2522 - val_accuracy: 0.9036
# Epoch 26/30
# 62/62 [==============================] - 141s 2s/step - loss: 0.3516 - accuracy: 0.8791 - val_loss: 0.3369 - val_accuracy: 0.8719
# Epoch 27/30
# 62/62 [==============================] - 142s 2s/step - loss: 0.3273 - accuracy: 0.8811 - val_loss: 0.2828 - val_accuracy: 0.8994
# Epoch 28/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3486 - accuracy: 0.8704 - val_loss: 0.3315 - val_accuracy: 0.8926
# Epoch 29/30
# 62/62 [==============================] - 141s 2s/step - loss: 0.3283 - accuracy: 0.8786 - val_loss: 0.2616 - val_accuracy: 0.9105
# Epoch 30/30
# 62/62 [==============================] - 141s 2s/step - loss: 0.3033 - accuracy: 0.8913 - val_loss: 0.3010 - val_accuracy: 0.8884

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#validation set :Its purpose is to track progress through validation loss and accuracy.
# plot accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
test_set = test_datagen.flow_from_directory('CHEST_xray/test',
                                                target_size = (500, 500),
                                                batch_size = 32,
                                                class_mode = 'categorical', shuffle= False)
# Out:
# Found 147 images belonging to 3 classes.

# %%
# Im trying to get individual prediction on all images  in test folder. write code to loop therough all images
# and give prediction . 
#All i need is that and i will make confusion matrix manually (by hand), after looking at predictions if need be 
test_image = image.load_img('CHEST_xray/test/covid/COVID-19 (59).png', target_size = (500, 500))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
training_set.class_indices
if result[0][0] > 0.5:
    prediction = 'Pneumonia'
else:
    prediction = 'Normal'

print(prediction)
# Out:
# Pneumonia

# %%
subfolders=["covid", "normal", "viral_pneumonia"]
#src_dir='CHEST_xray/test/covid'
#print(len(os.listdir(src_dir)))
# loop over images/files in the subfolders of the test folder
for actual in subfolders:
    src_dir='CHEST_xray/test/'+actual
    files=os.listdir(src_dir) 
    #print(len(files))
    for file in files:
        src_file_path=os.path.join(src_dir, file)
        #print(src_file_path)
        test_image = image.load_img(src_file_path, target_size = (500, 500))
        test_image = image.img_to_array(test_image)
        test_image = np.expand_dims(test_image, axis = 0)
        result = model.predict(test_image)
        training_set.class_indices
        if result[0][0] > 0.5:
            prediction = 'pneumonia'
        else:
            prediction = 'normal'

        print(actual, prediction)
# Out:
# covid pneumonia
# covid pneumonia
# covid pneumonia
# covid pneumonia
# covid pneumonia
# covid pneumonia
# covid pneumonia
# covid pneumonia
# covid pneumonia
# covid pneumonia
# covid pneumonia
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal pneumonia
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia pneumonia
# viral_pneumonia pneumonia
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia pneumonia
# viral_pneumonia pneumonia
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia pneumonia

# %%
subfolders=["covid", "normal", "viral_pneumonia"]
#src_dir='CHEST_xray/test/covid'
#print(len(os.listdir(src_dir)))
# loop over images/files in the subfolders of the test folder
for actual in subfolders:
    src_dir='CHEST_xray/test/'+actual
    files=os.listdir(src_dir) 
    #print(len(files))
    for file in files:
        src_file_path=os.path.join(src_dir, file)
        #print(src_file_path)
        test_image = image.load_img(src_file_path, target_size = (500, 500))
        test_image = image.img_to_array(test_image)
        test_image = np.expand_dims(test_image, axis = 0)
        result = model.predict(test_image)
        training_set.class_indices
        if result[0][0] > 0.5:
            prediction = 'normal'
        else:
            prediction = 'covid'

        print(actual, prediction)
# Out:
# covid normal
# covid normal
# covid normal
# covid normal
# covid normal
# covid normal
# covid normal
# covid normal
# covid normal
# covid normal
# covid normal
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal normal
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# normal covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia covid
# viral_pneumonia normal

# %%
#224
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
#from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
#from sklearn.metrics import roc_auc
from sklearn.metrics import auc
subfolders=["covid", "normal", "viral_pneumonia"]

# loop over images/files in the subfolders of the test folder
#actual_list=[]
prediction_list=[]
count_covid=0
count_normal=0
count_viral_pneumonia=0
for actual in subfolders:
    src_dir='CHEST_xray/test/'+actual
    files=os.listdir(src_dir) 
    print(len(files))
    
    
    
    for file in files:
        if file !="Thumbs.db":
            

            
                
            src_file_path=os.path.join(src_dir, file)
            #print(src_file_path)
            test_image = image.load_img(src_file_path, target_size = (500, 500))
            test_image = image.img_to_array(test_image)
            test_image = np.expand_dims(test_image, axis = 0)
            result = model.predict(test_image)
            #print(result)
            training_set.class_indices
            #capturing prediction in an array
            if int(result[0][0])==1:
                prediction = 'Covid'
                prediction_list.append(2)
                               
            
            elif int(result[0][1])==1:
                prediction = 'Normal'
                prediction_list.append(0)
                
                
         
                
            elif int(result[0][2])==1:
                
                prediction = 'Viral Pneumonia'
                prediction_list.append(1)
 
            else:
                continue
                        # capturing actual in an array    
            if actual=="covid":
          
                count_covid +=1
            
            elif actual=="normal":
         
                count_normal +=1
           
            elif actual=="viral_pneumonia":
                count_viral_pneumonia +=1
      
            #print(actual, prediction)

actual_list=[2]*count_covid+[0]*count_normal+[1]*count_viral_pneumonia
print(len(actual_list))
print(len(prediction_list))
print(count_covid, count_normal, count_viral_pneumonia)
# calculate metrics
print(accuracy_score(actual_list, prediction_list))
print(precision_score (actual_list, prediction_list, average= 'macro'))
print(recall_score (actual_list, prediction_list, average='macro'))
#print(roc_auc_score (actual_list, prediction_list, average='None')) 
print(confusion_matrix(actual_list, prediction_list)) 


#print(confusion_matrix (actual_list, prediction_list))
# Out:
# 11
# 68
# 68
# 139
# 139
# 11 66 62
# 0.7553956834532374
# 0.7002168643959689
# 0.8191593352883676
# [[60  5  1]
#  [ 7 34 21]
#  [ 0  0 11]]
