# %%
#importing libraries
import PIL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential 
from keras.layers import Convolution2D ,MaxPooling2D, Flatten, Dense,Dropout
from keras.utils import to_categorical
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
#from keras.layers import BatchNormalization
import os
import numpy as np
import warnings
warnings.filterwarnings('ignore')
##
seed=10
np.random.seed(seed)

# %%
#initialise the CNN model with different layers(used sequential): 3 layers
model = Sequential()
# Note the input shape is the desired size of the image 300x300 with 3 bytes color
# Step 1
model.add(Convolution2D(16,3,3, input_shape=(500, 500, 3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
#step 2 Convolution- learn features: put convolution filter on input(5X5) to get tensor output
model.add(Convolution2D(32,3,3, activation="relu"))

#step 3 Normalize the activations of the previous layer at each batch to increase stability and performance 
#model.add(BatchNormalization())

#step 4 reduce spatial dimension 
model.add(MaxPooling2D(pool_size =(2,2)))

#step 5 learn more features with activation function 'relu'to introduce non-lineraity (& avoid overfitting )
model.add(Convolution2D(64, 3, 3, activation = 'relu'))

#step 6 reduce spatial dimension
model.add(MaxPooling2D(pool_size=(2,2)))

#step 7 multidimensional to linear output
model.add(Flatten())

#step 8 connect every input to every output by weights (dot product)
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation = 'softmax'))

# %%
#loss function is default for multi-classification problem  
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
#augmentation configuration for training and testing 
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# used this code when I manually put images in folder train under CHEST_xrxay/train.
#now has to be done ramdomly with code because manually picking images to train etc is not good
# Can comment out if need be
#32
training_set = train_datagen.flow_from_directory('CHEST_xray/train',
                                                target_size = (500, 500),
                                                batch_size = 32,
                                                class_mode = 'categorical')
# Out:
# Found 2032 images belonging to 3 classes.

# %%
#used this code when I manually put images in folder train under CHEST_xrxay/validate
#now has to be done ramdomly with code because manually picking images is not good
# Can comment out if need be
validation_set = test_datagen.flow_from_directory('CHEST_xray/validate',
                                                target_size = (500, 500),
                                                batch_size = 32,
                                                class_mode = 'categorical')
# Out:
# Found 726 images belonging to 3 classes.

# %%
history=model.fit_generator(training_set,epochs =30,steps_per_epoch=62 ,validation_data = validation_set)
# Out:
# Epoch 1/30
# 62/62 [==============================] - 142s 2s/step - loss: 0.9565 - accuracy: 0.4604 - val_loss: 0.8966 - val_accuracy: 0.5882
# Epoch 2/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.8940 - accuracy: 0.5229 - val_loss: 0.8736 - val_accuracy: 0.6556
# Epoch 3/30
# 62/62 [==============================] - 139s 2s/step - loss: 0.8710 - accuracy: 0.5661 - val_loss: 0.8326 - val_accuracy: 0.6680
# Epoch 4/30
# 62/62 [==============================] - 138s 2s/step - loss: 0.8206 - accuracy: 0.6717 - val_loss: 0.7610 - val_accuracy: 0.8017
# Epoch 5/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.7592 - accuracy: 0.7002 - val_loss: 0.7085 - val_accuracy: 0.6818
# Epoch 6/30
# 62/62 [==============================] - 142s 2s/step - loss: 0.6993 - accuracy: 0.7332 - val_loss: 0.6038 - val_accuracy: 0.7934
# Epoch 7/30
# 62/62 [==============================] - 139s 2s/step - loss: 0.6466 - accuracy: 0.7480 - val_loss: 0.5375 - val_accuracy: 0.8196
# Epoch 8/30
# 62/62 [==============================] - 138s 2s/step - loss: 0.6033 - accuracy: 0.7678 - val_loss: 0.4902 - val_accuracy: 0.8099
# Epoch 9/30
# 62/62 [==============================] - 143s 2s/step - loss: 0.5492 - accuracy: 0.7922 - val_loss: 0.4672 - val_accuracy: 0.8237
# Epoch 10/30
# 62/62 [==============================] - 144s 2s/step - loss: 0.5129 - accuracy: 0.8023 - val_loss: 0.4221 - val_accuracy: 0.8333
# Epoch 11/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.4829 - accuracy: 0.8155 - val_loss: 0.4042 - val_accuracy: 0.8361
# Epoch 12/30
# 62/62 [==============================] - 142s 2s/step - loss: 0.4635 - accuracy: 0.8247 - val_loss: 0.3707 - val_accuracy: 0.8664
# Epoch 13/30
# 62/62 [==============================] - 143s 2s/step - loss: 0.4581 - accuracy: 0.8308 - val_loss: 0.3514 - val_accuracy: 0.8788
# Epoch 14/30
# 62/62 [==============================] - 145s 2s/step - loss: 0.4312 - accuracy: 0.8394 - val_loss: 0.3427 - val_accuracy: 0.8747
# Epoch 15/30
# 62/62 [==============================] - 146s 2s/step - loss: 0.4168 - accuracy: 0.8425 - val_loss: 0.3304 - val_accuracy: 0.8788
# Epoch 16/30
# 62/62 [==============================] - 145s 2s/step - loss: 0.4125 - accuracy: 0.8420 - val_loss: 0.3263 - val_accuracy: 0.8760
# Epoch 17/30
# 62/62 [==============================] - 141s 2s/step - loss: 0.4058 - accuracy: 0.8486 - val_loss: 0.3112 - val_accuracy: 0.8898
# Epoch 18/30
# 62/62 [==============================] - 141s 2s/step - loss: 0.4044 - accuracy: 0.8511 - val_loss: 0.3065 - val_accuracy: 0.8953
# Epoch 19/30
# 62/62 [==============================] - 143s 2s/step - loss: 0.4063 - accuracy: 0.8491 - val_loss: 0.3048 - val_accuracy: 0.8871
# Epoch 20/30
# 62/62 [==============================] - 139s 2s/step - loss: 0.3672 - accuracy: 0.8684 - val_loss: 0.2939 - val_accuracy: 0.8912
# Epoch 21/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3780 - accuracy: 0.8577 - val_loss: 0.3033 - val_accuracy: 0.8843
# Epoch 22/30
# 62/62 [==============================] - 139s 2s/step - loss: 0.3725 - accuracy: 0.8653 - val_loss: 0.2870 - val_accuracy: 0.8939
# Epoch 23/30
# 62/62 [==============================] - 138s 2s/step - loss: 0.3809 - accuracy: 0.8598 - val_loss: 0.2934 - val_accuracy: 0.8912
# Epoch 24/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3811 - accuracy: 0.8557 - val_loss: 0.2861 - val_accuracy: 0.8953
# Epoch 25/30
# 62/62 [==============================] - 139s 2s/step - loss: 0.3720 - accuracy: 0.8608 - val_loss: 0.2873 - val_accuracy: 0.8939
# Epoch 26/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3640 - accuracy: 0.8592 - val_loss: 0.2955 - val_accuracy: 0.8926
# Epoch 27/30
# 62/62 [==============================] - 144s 2s/step - loss: 0.3708 - accuracy: 0.8613 - val_loss: 0.2822 - val_accuracy: 0.8926
# Epoch 28/30
# 62/62 [==============================] - 138s 2s/step - loss: 0.3368 - accuracy: 0.8755 - val_loss: 0.2800 - val_accuracy: 0.8994
# Epoch 29/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3617 - accuracy: 0.8638 - val_loss: 0.2813 - val_accuracy: 0.8967
# Epoch 30/30
# 62/62 [==============================] - 140s 2s/step - loss: 0.3484 - accuracy: 0.8725 - val_loss: 0.2733 - val_accuracy: 0.9008

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#validation set :Its purpose is to track progress through validation loss and accuracy.
# plot accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
test_set = test_datagen.flow_from_directory('CHEST_xray/test',
                                                target_size = (500, 500),
                                                batch_size = 32,
                                                class_mode = 'categorical', shuffle= False)
# Out:
# Found 147 images belonging to 3 classes.

# %%
subfolders=["covid", "normal", "viral_pneumonia"]
#src_dir='CHEST_xray/test/covid'
#print(len(os.listdir(src_dir)))
# loop over images/files in the subfolders of the test folder
for actual in subfolders:
    src_dir='CHEST_xray/test/'+actual
    files=os.listdir(src_dir) 
    #print(len(files))
    for file in files:
        src_file_path=os.path.join(src_dir, file)
        #print(src_file_path)
        test_image = image.load_img(src_file_path, target_size = (500, 500))
        test_image = image.img_to_array(test_image)
        test_image = np.expand_dims(test_image, axis = 0)
        result = model.predict(test_image)
        training_set.class_indices
        if result[0][0] > 0.5:
            prediction = 'covid'
        else:
            prediction = 'normal'

        print(actual, prediction)
# Out:
# covid normal
# covid covid
# covid normal
# covid covid
# covid covid
# covid normal
# covid covid
# covid covid
# covid covid
# covid normal
# covid normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# normal normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal
# viral_pneumonia normal

# %%
#224
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
#from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
#from sklearn.metrics import roc_auc
from sklearn.metrics import auc
subfolders=["covid", "normal", "viral_pneumonia"]

# loop over images/files in the subfolders of the test folder
#actual_list=[]
prediction_list=[]
count_covid=0
count_normal=0
count_viral_pneumonia=0
for actual in subfolders:
    src_dir='CHEST_xray/test/'+actual
    files=os.listdir(src_dir) 
    print(len(files))
    
    
    
    for file in files:
        if file !="Thumbs.db":
            

            
                
            src_file_path=os.path.join(src_dir, file)
            #print(src_file_path)
            test_image = image.load_img(src_file_path, target_size = (500, 500))
            test_image = image.img_to_array(test_image)
            test_image = np.expand_dims(test_image, axis = 0)
            result = model.predict(test_image)
            #print(result)
            training_set.class_indices
            #capturing prediction in an array
            if int(result[0][0])==1:
                prediction = 'Covid'
                prediction_list.append(2)
                               
            
            elif int(result[0][1])==1:
                prediction = 'Normal'
                prediction_list.append(0)
                
                
         
                
            elif int(result[0][2])==1:
                
                prediction = 'Viral Pneumonia'
                prediction_list.append(1)
 
            else:
                continue
                        # capturing actual in an array    
            if actual=="covid":
          
                count_covid +=1
            
            elif actual=="normal":
         
                count_normal +=1
           
            elif actual=="viral_pneumonia":
                count_viral_pneumonia +=1
      
            #print(actual, prediction)

actual_list=[2]*count_covid+[0]*count_normal+[1]*count_viral_pneumonia
print(len(actual_list))
print(len(prediction_list))
print(count_covid, count_normal, count_viral_pneumonia)
# calculate metrics
print(accuracy_score(actual_list, prediction_list))
print(precision_score (actual_list, prediction_list, average= 'macro'))
print(recall_score (actual_list, prediction_list, average='macro'))
#print(roc_auc_score (actual_list, prediction_list, average='None')) 
print(confusion_matrix(actual_list, prediction_list)) 


#print(confusion_matrix (actual_list, prediction_list))
# Out:
# 11
# 68
# 68
# 147
# 147
# 11 68 68
# 0.8503401360544217
# 0.911663807890223
# 0.7651515151515151
# [[68  0  0]
#  [17 51  0]
#  [ 3  2  6]]
